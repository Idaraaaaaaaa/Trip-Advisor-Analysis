# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('database.db')

# %%
query = "SELECT name FROM sqlite_master WHERE type='table';"
df = pd.read_sql_query(query, conn)
df
# Out:
#    name
# 0  data

# %%
query = "SELECT * FROM data;"
df = pd.read_sql_query(query, conn)
df
# Out:
#     User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 0            USA           11                  4             13      5
# 1            USA          119                 21             75      3
# 2            USA           36                  9             25      5
# 3             UK           14                  7             14      4
# 4         Canada            5                  5              2      4
# ..           ...          ...                ...            ...    ...
# 499           UK           15                  4              8      5
# 500       Canada           50                 13             29      4
# 501          USA          154                 23             31      4
# 502          USA            9                  6              5      2
# 503          USA           20                 19            112      4
#
#     Period of stay Traveler type Swimming Pool Exercise Room Basketball Court  \
# 0          Dec-Feb       Friends            NO           YES               NO
# 1          Dec-Feb      Business            NO           YES               NO
# 2          Mar-May      Families            NO           YES               NO
# 3          Mar-May       Friends            NO           YES               NO
# 4          Mar-May          Solo            NO           YES               NO
# ..             ...           ...           ...           ...              ...
# 499        Sep-Nov       Couples           YES           YES               NO
# 500        Sep-Nov       Couples           YES           YES               NO
# 501        Sep-Nov       Friends           YES           YES               NO
# 502        Dec-Feb      Families           YES           YES               NO
# 503        Dec-Feb      Families           YES           YES               NO
#
#     Yoga Classes Club Free Wifi                               Hotel name  \
# 0             NO  YES       YES   Circus Circus Hotel & Casino Las Vegas
# 1             NO  YES       YES   Circus Circus Hotel & Casino Las Vegas
# 2             NO  YES       YES   Circus Circus Hotel & Casino Las Vegas
# 3             NO  YES       YES   Circus Circus Hotel & Casino Las Vegas
# 4             NO  YES       YES   Circus Circus Hotel & Casino Las Vegas
# ..           ...  ...       ...                                      ...
# 499          YES  YES       YES  The Westin las Vegas Hotel Casino & Spa
# 500          YES  YES       YES  The Westin las Vegas Hotel Casino & Spa
# 501          YES  YES       YES  The Westin las Vegas Hotel Casino & Spa
# 502          YES  YES       YES  The Westin las Vegas Hotel Casino & Spa
# 503          YES  YES       YES  The Westin las Vegas Hotel Casino & Spa
#
#     Hotel stars  Nr. rooms User continent  Member years Review month  \
# 0             3       3773  North America             9      January
# 1             3       3773  North America             3      January
# 2             3       3773  North America             2     February
# 3             3       3773         Europe             6     February
# 4             3       3773  North America             7        March
# ..          ...        ...            ...           ...          ...
# 499           4        826         Europe             1      October
# 500           4        826  North America             8     November
# 501           4        826  North America             4     November
# 502           4        826  North America             9     December
# 503           4        826  North America             5     December
#
#     Review weekday
# 0         Thursday
# 1           Friday
# 2         Saturday
# 3           Friday
# 4          Tuesday
# ..             ...
# 499         Sunday
# 500       Thursday
# 501       Thursday
# 502      Wednesday
# 503        Tuesday
#
# [504 rows x 20 columns]

# %%
query = "SELECT * FROM data;"
df = pd.read_sql_query(query, conn)
df.to_csv('trip_advisor.csv', index=False)

# %%
conn.close()
